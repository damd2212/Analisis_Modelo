# %%
# %load_ext watermark
# %watermark
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# Last updated: 2023-06-02T15:33:53.266059-05:00
#
# Python implementation: CPython
# Python version       : 3.10.11
# IPython version      : 8.13.2
#
# Compiler    : MSC v.1916 64 bit (AMD64)
# OS          : Windows
# Release     : 10
# Machine     : AMD64
# Processor   : Intel64 Family 6 Model 158 Stepping 10, GenuineIntel
# CPU cores   : 8
# Architecture: 64bit

# %% [markdown]
# Aquí incluyo unas herramientas que son bastante útiles a la hora de hacer EDA

# %% [markdown]
# ### Ingesta de datos

# %%
import pandas as pd

vehiculos = pd.read_csv("C:/Users/Danny/Desktop/Ciencia_datos_curso_tesis/Analisis exploratorio de datos/data/vehiculos_1_procesado_inicial.csv")

# %% [markdown]
# ### Pandas-profiling
#
# https://github.com/JosPolfliet/pandas-profiling

# %%
import sys
#!conda install --yes --prefix {sys.prefix} pandas-profiling==2.7.1
# !{sys.executable} -m pip install -U pandas-profiling==3.2.0
# Out:
# ...
#      ---------------------------------------- 0.0/262.6 kB ? eta -:--:--
#      ----------------------------- -------- 204.8/262.6 kB 6.3 MB/s eta 0:00:01
#      -------------------------------------- 262.6/262.6 kB 8.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/309.8 kB ? eta -:--:--
#      ------------------------------------  307.2/309.8 kB 19.8 MB/s eta 0:00:01
#      -------------------------------------- 309.8/309.8 kB 6.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/102.4 kB ? eta -:--:--
#      ---------------------------------------- 102.4/102.4 kB ? eta 0:00:00
# ...
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.2.0
#     Uninstalling joblib-1.2.0:
#       Successfully uninstalled joblib-1.2.0
#   Attempting uninstall: visions
#     Found existing installation: visions 0.7.5
#     Uninstalling visions-0.7.5:
#       Successfully uninstalled visions-0.7.5
#   Attempting uninstall: pandas-profiling
# ...

# %%
import pandas_profiling

pandas_profiling.ProfileReport(vehiculos)
# Out:
# C:\Users\Danny\.conda\envs\data\lib\multiprocessing\pool.py:478: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   iterable = list(iterable)

# %%
# %matplotlib inline

# %% [markdown]
# ### Missigno
#
# https://github.com/ResidentMario/missingno

# %%
# !conda install -y missingno
# Out:
# Fetching package metadata ...............
# Solving package specifications: .
#
# Package plan for installation in environment /home/manuel/anaconda3/envs/data:
#
# The following NEW packages will be INSTALLED:
#
#     missingno: 0.3.7-py36_0 conda-forge
#
# missingno-0.3. 100% |################################| Time: 0:00:00 207.63 kB/s

# %%
import missingno as msno

msno.matrix(vehiculos)

# %%
msno.heatmap(vehiculos)
