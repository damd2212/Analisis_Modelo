# %%
# %load_ext watermark
# %watermark
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# Last updated: 2023-06-14T12:42:07.797245-05:00
#
# Python implementation: CPython
# Python version       : 3.10.11
# IPython version      : 8.13.2
#
# Compiler    : MSC v.1916 64 bit (AMD64)
# OS          : Windows
# Release     : 10
# Machine     : AMD64
# Processor   : Intel64 Family 6 Model 158 Stepping 10, GenuineIntel
# CPU cores   : 8
# Architecture: 64bit

# %%
import pandas as pd

# %%
consumidores = pd.read_csv("C:/Users/Danny/Desktop/Analisis tesis/Analisis exploratorio de datos/data/dataset-final.csv")
consumidores.head()
# Out:
#    directorio  per_sexo  per_edad  vive_padre_hogar  vive_madre_hogar  \
# 0       11207         1        19                 2                 2
# 1        1180         2        51                 2                 1
# 2        4398         1        52                 3                 3
# 3        4399         2        39                 1                 1
# 4        2619         2        27                 1                 1
#
#   departamento              municipio  tipo_vivienda  servicio_energia  \
# 0     Guaviare  SAN JOSÉ DEL GUAVIARE              2                 1
# 1      Cordoba               MONTERÍA              1                 1
# 2      Caqueta              FLORENCIA              1                 1
# 3      Bolivar              CARTAGENA              1                 1
# 4       Tolima                ESPINAL              1                 1
#
#    estrato  ...  g_11_j_consumio_alguna_vez_heroina  \
# 0      2.0  ...                                   2
# 1      1.0  ...                                   2
# 2      2.0  ...                                   2
# 3      5.0  ...                                   2
# 4      2.0  ...                                   2
#
#    g_11_j_anios_consumio_heroina  k_03_consumio_marihuana_12m  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#    k_04_frecuencia_consumo_marihuana_12m  l_02_consumio_cocaina_12m  \
# 0                                    NaN                        NaN
# 1                                    NaN                        NaN
# 2                                    NaN                        NaN
# 3                                    NaN                        NaN
# 4                                    NaN                        NaN
#
#    l_03_frecuencia_consumo_cocaina_12m  m_02_consumio_basuco_12m  \
# 0                                  NaN                       NaN
# 1                                  NaN                       NaN
# 2                                  NaN                       NaN
# 3                                  NaN                       NaN
# 4                                  NaN                       NaN
#
#    m_03_frecuencia_consumo_basuco_12m  0_02_consumio_heroina_12m  \
# 0                                 NaN                        NaN
# 1                                 NaN                        NaN
# 2                                 NaN                        NaN
# 3                                 NaN                        NaN
# 4                                 NaN                        NaN
#
#    0_03_frecuencia_consumo_heroina_12m
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
# [5 rows x 57 columns]

# %%
consumidores = consumidores.rename(columns={
    "d_11_h_riesgo_fumar_marihuana_frecuentemente":"d_11_h_conocimiento_riesgo_fumar_marihuana_frecuentemente",
    "d_11_k_riesgo_cocaina_frecuentemente":"d_11_k_conocimiento_riesgo_cocaina_frecuentemente",
    "d_11_n_riesgo_fumar_basuco_frecuentemente":"d_11_n_conocimiento_riesgo_fumar_basuco_frecuentemente",
    "d_12_b_consumo_sp_barrio":"d_12_b_presenta_problema_consumo_sp_barrio",
    "d_12_c_expendio_sp_barrio":"d_12_c_presenta_problema_expendio_sp_barrio",
    "0_02_consumio_heroina_12m":"o_02_consumio_heroina_12m",
    "0_03_frecuencia_consumo_heroina_12m":"o_03_frecuencia_consumo_heroina_12m",
})

# %%
consumidores.dtypes
# Out:
# directorio                                                     int64
# per_sexo                                                       int64
# per_edad                                                       int64
# vive_padre_hogar                                               int64
# vive_madre_hogar                                               int64
# departamento                                                  object
# municipio                                                     object
# tipo_vivienda                                                  int64
# servicio_energia                                               int64
# estrato                                                      float64
# residentes_hogar                                               int64
# d_01_aporta_dinero_hogar                                       int64
# d_02_situacion_actual                                          int64
# d_08_estado_salud                                              int64
# d_09_deprimido                                                 int64
# d_10_poco_interes                                              int64
# d_11_h_conocimiento_riesgo_fumar_marihuana_frecuentemente      int64
# d_11_k_conocimiento_riesgo_cocaina_frecuentemente              int64
# d_11_n_conocimiento_riesgo_fumar_basuco_frecuentemente         int64
# d_12_b_presenta_problema_consumo_sp_barrio                     int64
# d_12_c_presenta_problema_expendio_sp_barrio                    int64
# d2_01_etnia                                                    int64
# d2_03_estado_civil                                             int64
# d2_04_num_hijos                                                int64
# d2_05_nivel_educativo                                          int64
# g_01_familiares_consumen_sp                                    int64
# g_01_a_num_familiares_consumen_sp                            float64
# g_02_amigos_consumen_sp                                        int64
# g_02_a_num_amigos_consumen_sp                                float64
# g_03_curiosidad_probar_sp                                      int64
# g_04_probaria_sp                                               int64
# g_05_posibilidad_probar_sp                                     int64
# g_06_a_posibilidad_conseguir_marihuana                         int64
# g_06_b_posibilidad_conseguir_cocaina                           int64
# g_06_c_posibilidad_conseguir_basuco                            int64
# g_06_j_posibilidad_conseguir_heroina                           int64
# g_07_alguien_ofrecio_comprar_probar_sp                         int64
# g_08_a_ofrecieron_marihuana                                  float64
# g_08_b_ofrecieron_cocaina                                    float64
# g_08_c_ofrecieron_basuco                                     float64
# g_08_e_ofrecieron_heroina                                    float64
# g_11_f_consumio_alguna_vez_marihuana                           int64
# g_11_f_anios_consumio_marihuana                              float64
# g_11_g_consumio_alguna_vez_cocaina                             int64
# g_11_g_anios_consumio_cocaina                                float64
# g_11_h_consumio_alguna_vez_basuco                              int64
# g_11_h_anios_consumio_basuco                                 float64
# g_11_j_consumio_alguna_vez_heroina                             int64
# g_11_j_anios_consumio_heroina                                float64
# k_03_consumio_marihuana_12m                                  float64
# k_04_frecuencia_consumo_marihuana_12m                        float64
# l_02_consumio_cocaina_12m                                    float64
# l_03_frecuencia_consumo_cocaina_12m                          float64
# m_02_consumio_basuco_12m                                     float64
# m_03_frecuencia_consumo_basuco_12m                           float64
# o_02_consumio_heroina_12m                                    float64
# o_03_frecuencia_consumo_heroina_12m                          float64
# dtype: object

# %%
consumidores.shape
# Out:
# (10149, 57)

# %% [markdown]
# # Tipos de datos del dataframe

# %%
consumidores.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10149 entries, 0 to 10148
# Data columns (total 57 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   directorio                                                 10149 non-null  int64
#  1   per_sexo                                                   10149 non-null  int64
#  2   per_edad                                                   10149 non-null  int64
#  3   vive_padre_hogar                                           10149 non-null  int64
#  4   vive_madre_hogar                                           10149 non-null  int64
#  5   departamento                                               10149 non-null  object
#  6   municipio                                                  10149 non-null  object
#  7   tipo_vivienda                                              10149 non-null  int64
#  8   servicio_energia                                           10149 non-null  int64
#  9   estrato                                                    10127 non-null  float64
#  10  residentes_hogar                                           10149 non-null  int64
#  11  d_01_aporta_dinero_hogar                                   10149 non-null  int64
#  12  d_02_situacion_actual                                      10149 non-null  int64
#  13  d_08_estado_salud                                          10149 non-null  int64
#  14  d_09_deprimido                                             10149 non-null  int64
#  15  d_10_poco_interes                                          10149 non-null  int64
#  16  d_11_h_conocimiento_riesgo_fumar_marihuana_frecuentemente  10149 non-null  int64
#  17  d_11_k_conocimiento_riesgo_cocaina_frecuentemente          10149 non-null  int64
#  18  d_11_n_conocimiento_riesgo_fumar_basuco_frecuentemente     10149 non-null  int64
#  19  d_12_b_presenta_problema_consumo_sp_barrio                 10149 non-null  int64
#  20  d_12_c_presenta_problema_expendio_sp_barrio                10149 non-null  int64
#  21  d2_01_etnia                                                10149 non-null  int64
#  22  d2_03_estado_civil                                         10149 non-null  int64
#  23  d2_04_num_hijos                                            10149 non-null  int64
#  24  d2_05_nivel_educativo                                      10149 non-null  int64
#  25  g_01_familiares_consumen_sp                                10149 non-null  int64
#  26  g_01_a_num_familiares_consumen_sp                          2806 non-null   float64
#  27  g_02_amigos_consumen_sp                                    10149 non-null  int64
#  28  g_02_a_num_amigos_consumen_sp                              4371 non-null   float64
#  29  g_03_curiosidad_probar_sp                                  10149 non-null  int64
#  30  g_04_probaria_sp                                           10149 non-null  int64
#  31  g_05_posibilidad_probar_sp                                 10149 non-null  int64
#  32  g_06_a_posibilidad_conseguir_marihuana                     10149 non-null  int64
#  33  g_06_b_posibilidad_conseguir_cocaina                       10149 non-null  int64
#  34  g_06_c_posibilidad_conseguir_basuco                        10149 non-null  int64
#  35  g_06_j_posibilidad_conseguir_heroina                       10149 non-null  int64
#  36  g_07_alguien_ofrecio_comprar_probar_sp                     10149 non-null  int64
#  37  g_08_a_ofrecieron_marihuana                                4942 non-null   float64
#  38  g_08_b_ofrecieron_cocaina                                  4942 non-null   float64
#  39  g_08_c_ofrecieron_basuco                                   4942 non-null   float64
#  40  g_08_e_ofrecieron_heroina                                  4942 non-null   float64
#  41  g_11_f_consumio_alguna_vez_marihuana                       10149 non-null  int64
#  42  g_11_f_anios_consumio_marihuana                            3982 non-null   float64
#  43  g_11_g_consumio_alguna_vez_cocaina                         10149 non-null  int64
#  44  g_11_g_anios_consumio_cocaina                              973 non-null    float64
#  45  g_11_h_consumio_alguna_vez_basuco                          10149 non-null  int64
#  46  g_11_h_anios_consumio_basuco                               3982 non-null   float64
#  47  g_11_j_consumio_alguna_vez_heroina                         10149 non-null  int64
#  48  g_11_j_anios_consumio_heroina                              49 non-null     float64
#  49  k_03_consumio_marihuana_12m                                3982 non-null   float64
#  50  k_04_frecuencia_consumo_marihuana_12m                      1223 non-null   float64
#  51  l_02_consumio_cocaina_12m                                  973 non-null    float64
#  52  l_03_frecuencia_consumo_cocaina_12m                        248 non-null    float64
#  53  m_02_consumio_basuco_12m                                   310 non-null    float64
#  54  m_03_frecuencia_consumo_basuco_12m                         57 non-null     float64
#  55  o_02_consumio_heroina_12m                                  49 non-null     float64
#  56  o_03_frecuencia_consumo_heroina_12m                        5 non-null      float64
# dtypes: float64(19), int64(36), object(2)
# memory usage: 4.4+ MB

# %%
consumidores.to_csv("C:/Users/Danny/Desktop/Analisis tesis/Analisis exploratorio de datos/data/consumidores.1.procesado_inicial.csv", index=False)
