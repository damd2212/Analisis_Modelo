# %%
import pandas as pd

# %%
consumidores = pd.read_csv("C:/Users/Danny/Desktop/Analisis tesis/Analisis exploratorio de datos/data/dataset-final-consumen.csv")
consumidores.head()
# Out:
#    directorio  per_sexo  per_edad  vive_padre_hogar  vive_madre_hogar  \
# 0         290         1        40                 2                 2
# 1         535         2        23                 2                 2
# 2         827         1        30                 2                 2
# 3        1535         1        34                 1                 1
# 4        1742         1        17                 2                 3
#
#   departamento              municipio  tipo_vivienda  servicio_energia  \
# 0     Guaviare  SAN JOSÉ DEL GUAVIARE              3                 1
# 1    Santander            PIEDECUESTA              2                 1
# 2     Guaviare  SAN JOSÉ DEL GUAVIARE              1                 1
# 3        Valle                   CALI              1                 1
# 4      Caqueta              FLORENCIA              1                 1
#
#    estrato  ...  g_11_j_consumio_alguna_vez_heroina  \
# 0      2.0  ...                                   1
# ...

# %%
no_consumidores = pd.read_csv("C:/Users/Danny/Desktop/Analisis tesis/Analisis exploratorio de datos/data/dataset-final-no-consumen.csv")
no_consumidores.head()
# Out:
#    directorio  per_sexo  per_edad  vive_padre_hogar  vive_madre_hogar  \
# 0           2         2        62                 2                 2
# 1           4         2        64                 3                 3
# 2           6         2        46                 2                 2
# 3           8         2        33                 2                 2
# 4          11         2        27                 2                 2
#
#   departamento municipio  tipo_vivienda  servicio_energia  estrato  ...  \
# 0       Boyaca     TUNJA              1                 1      2.0  ...
# 1       Boyaca     TUNJA              1                 1      2.0  ...
# 2        Sucre   COROZAL              1                 1      1.0  ...
# 3      Cordoba  MONTERÍA              2                 1      3.0  ...
# 4      Cordoba  MONTERÍA              2                 1      3.0  ...
#
#    g_11_j_consumio_alguna_vez_heroina  g_11_j_anios_consumio_heroina  \
# ...

# %%
df_unido = pd.concat([consumidores, no_consumidores])
df_unido.head()
# Out:
#    directorio  per_sexo  per_edad  vive_padre_hogar  vive_madre_hogar  \
# 0         290         1        40                 2                 2
# 1         535         2        23                 2                 2
# 2         827         1        30                 2                 2
# 3        1535         1        34                 1                 1
# 4        1742         1        17                 2                 3
#
#   departamento              municipio  tipo_vivienda  servicio_energia  \
# 0     Guaviare  SAN JOSÉ DEL GUAVIARE              3                 1
# 1    Santander            PIEDECUESTA              2                 1
# 2     Guaviare  SAN JOSÉ DEL GUAVIARE              1                 1
# 3        Valle                   CALI              1                 1
# 4      Caqueta              FLORENCIA              1                 1
#
#    estrato  ...  g_11_j_consumio_alguna_vez_heroina  \
# 0      2.0  ...                                   1
# ...

# %%
df_unido.shape
# Out:
# (10149, 57)

# %%
df_shuffled = df_unido.sample(frac=1).reset_index(drop=True)
df_shuffled.head()
# Out:
#    directorio  per_sexo  per_edad  vive_padre_hogar  vive_madre_hogar  \
# 0       11207         1        19                 2                 2
# 1        1180         2        51                 2                 1
# 2        4398         1        52                 3                 3
# 3        4399         2        39                 1                 1
# 4        2619         2        27                 1                 1
#
#   departamento              municipio  tipo_vivienda  servicio_energia  \
# 0     Guaviare  SAN JOSÉ DEL GUAVIARE              2                 1
# 1      Cordoba               MONTERÍA              1                 1
# 2      Caqueta              FLORENCIA              1                 1
# 3      Bolivar              CARTAGENA              1                 1
# 4       Tolima                ESPINAL              1                 1
#
#    estrato  ...  g_11_j_consumio_alguna_vez_heroina  \
# 0      2.0  ...                                   2
# ...

# %%
df_shuffled.shape
# Out:
# (10149, 57)

# %%
df_shuffled.to_csv("C:/Users/Danny/Desktop/Analisis tesis/Analisis exploratorio de datos/data/dataset-final.csv", index=False)
