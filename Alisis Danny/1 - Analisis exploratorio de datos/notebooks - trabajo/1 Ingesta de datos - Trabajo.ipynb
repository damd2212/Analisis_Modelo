# %%
# %load_ext watermark
# %watermark
# Out:
# Last updated: 2023-06-05T11:27:41.389272-05:00
#
# Python implementation: CPython
# Python version       : 3.10.11
# IPython version      : 8.13.2
#
# Compiler    : MSC v.1916 64 bit (AMD64)
# OS          : Windows
# Release     : 10
# Machine     : AMD64
# Processor   : Intel64 Family 6 Model 158 Stepping 10, GenuineIntel
# CPU cores   : 8
# Architecture: 64bit

# %%
import pandas as pd

# %%
consumidores_trabajo = pd.read_csv("C:/Users/Danny/Desktop/Analisis tesis/Analisis exploratorio de datos/data/dataset-final-trabajo.csv")
consumidores_trabajo.head()
# Out:
#    directorio  per_sexo  per_edad  vive_padre_hogar  vive_madre_hogar  \
# 0           3         1        54                 3                 2
# 1           6         2        46                 2                 2
# 2           7         1        33                 2                 2
# 3           8         2        33                 2                 2
# 4          11         2        27                 2                 2
#
#   departamento municipio  tipo_vivienda  servicio_energia  estrato  ...  \
# 0       Boyaca     TUNJA              2                 1      3.0  ...
# 1        Sucre   COROZAL              1                 1      1.0  ...
# 2        Sucre   COROZAL              1                 1      1.0  ...
# 3      Cordoba  MONTERÍA              2                 1      3.0  ...
# 4      Cordoba  MONTERÍA              2                 1      3.0  ...
#
#    r_01_accidente_laboral  r_02_consumio_sp_en_accidente_laboral  \
# 0                       2                                    NaN
# 1                       2                                    NaN
# 2                       2                                    NaN
# 3                       2                                    NaN
# 4                       2                                    NaN
#
#    r_03_estuvo_enfermo_accidentado_ult_30d  r_04_consecuencia_sp  \
# 0                                        0                   NaN
# 1                                        0                   NaN
# 2                                        0                   NaN
# 3                                        0                   NaN
# 4                                        0                   NaN
#
#    r_05_existe_reglamento_sp_trabajo  r_06_prevencion_sp_trabajo  \
# 0                                  2                           2
# 1                                  2                           2
# 2                                  1                           1
# 3                                  9                           2
# 4                                  1                           2
#
#    r_07_programa_ayuda_sp  r_08_c_consumo_marihuana_trabajo  \
# 0                       2                                 9
# 1                       2                                 9
# 2                       1                                 9
# 3                       9                                 9
# 4                       9                                 9
#
#    r_08_d_consumo_cocaina_trabajo  r_09_rendimiento_disminuido_trabajo
# 0                               9                                    2
# 1                               9                                    2
# 2                               9                                    9
# 3                               9                                    2
# 4                               9                                    2
#
# [5 rows x 59 columns]

# %%
consumidores_trabajo = consumidores_trabajo.rename(columns={
    "d_11_h_riesgo_fumar_marihuana_frecuentemente":"d_11_h_conocimiento_riesgo_fumar_marihuana_frecuentemente",
    "d_11_k_riesgo_cocaina_frecuentemente":"d_11_k_conocimiento_riesgo_cocaina_frecuentemente",
    "d_11_n_riesgo_fumar_basuco_frecuentemente":"d_11_n_conocimiento_riesgo_fumar_basuco_frecuentemente",
    "d_12_b_consumo_sp_barrio":"d_12_b_presenta_problema_consumo_sp_barrio",
    "d_12_c_expendio_sp_barrio":"d_12_c_presenta_problema_expendio_sp_barrio",
    "r_04_consecuencia_sp":"r_04_consecuencia_sp_r_03",
    "r_07_programa_ayuda_sp":"r_07_programa_ayuda_sp_trabajo",
    "r_08_c_consumo_marihuana_trabajo":"r_08_c_consumo_marihuana_en_trabajo",
    "r_08_d_consumo_cocaina_trabajo":"r_08_d_consumo_cocaina_en_trabajo",
})

# %%
consumidores_trabajo.dtypes
# Out:
# directorio                                                     int64
# per_sexo                                                       int64
# per_edad                                                       int64
# vive_padre_hogar                                               int64
# vive_madre_hogar                                               int64
# departamento                                                  object
# municipio                                                     object
# tipo_vivienda                                                  int64
# servicio_energia                                               int64
# estrato                                                      float64
# residentes_hogar                                               int64
# d_01_aporta_dinero_hogar                                       int64
# d_03_actividad_economica_empresa_negocio                       int64
# d_04_cargo                                                     int64
# d_08_estado_salud                                              int64
# d_09_deprimido                                                 int64
# d_10_poco_interes                                              int64
# d_11_h_conocimiento_riesgo_fumar_marihuana_frecuentemente      int64
# d_11_k_conocimiento_riesgo_cocaina_frecuentemente              int64
# d_11_n_conocimiento_riesgo_fumar_basuco_frecuentemente         int64
# d_12_b_presenta_problema_consumo_sp_barrio                     int64
# d_12_c_presenta_problema_expendio_sp_barrio                    int64
# d2_01_etnia                                                    int64
# d2_03_estado_civil                                             int64
# d2_04_num_hijos                                                int64
# d2_05_nivel_educativo                                          int64
# g_01_familiares_consumen_sp                                    int64
# g_01_a_num_familiares_consumen_sp                            float64
# g_02_amigos_consumen_sp                                        int64
# g_02_a_num_amigos_consumen_sp                                float64
# g_03_curiosidad_probar_sp                                      int64
# g_05_posibilidad_probar_sp                                     int64
# g_06_a_posibilidad_conseguir_marihuana                         int64
# g_06_b_posibilidad_conseguir_cocaina                           int64
# g_06_c_posibilidad_conseguir_basuco                            int64
# g_06_j_posibilidad_conseguir_heroina                           int64
# g_07_alguien_ofrecio_comprar_probar_sp                         int64
# g_08_a_ofrecieron_marihuana                                  float64
# g_08_b_ofrecieron_cocaina                                    float64
# g_08_c_ofrecieron_basuco                                     float64
# g_08_e_ofrecieron_heroina                                    float64
# g_11_f_consumio_alguna_vez_marihuana                           int64
# g_11_f_anios_consumio_marihuana                              float64
# g_11_g_consumio_alguna_vez_cocaina                             int64
# g_11_g_anios_consumio_cocaina                                float64
# g_11_h_consumio_alguna_vez_basuco                              int64
# g_11_h_anios_consumio_basuco                                 float64
# g_11_j_consumio_alguna_vez_heroina                             int64
# g_11_j_anios_consumio_heroina                                float64
# r_01_accidente_laboral                                         int64
# r_02_consumio_sp_en_accidente_laboral                        float64
# r_03_estuvo_enfermo_accidentado_ult_30d                        int64
# r_04_consecuencia_sp                                         float64
# r_05_existe_reglamento_sp_trabajo                              int64
# r_06_prevencion_sp_trabajo                                     int64
# r_07_programa_ayuda_sp                                         int64
# r_08_c_consumo_marihuana_trabajo                               int64
# r_08_d_consumo_cocaina_trabajo                                 int64
# r_09_rendimiento_disminuido_trabajo                            int64
# dtype: object

# %%
consumidores_trabajo.shape
# Out:
# (28691, 59)

# %% [markdown]
# # Tipos de datos del dataframe

# %%
consumidores_trabajo.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28691 entries, 0 to 28690
# Data columns (total 59 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   directorio                                    28691 non-null  int64
#  1   per_sexo                                      28691 non-null  int64
#  2   per_edad                                      28691 non-null  int64
#  3   vive_padre_hogar                              28691 non-null  int64
#  4   vive_madre_hogar                              28691 non-null  int64
#  5   departamento                                  28691 non-null  object
#  6   municipio                                     28691 non-null  object
#  7   tipo_vivienda                                 28691 non-null  int64
#  8   servicio_energia                              28691 non-null  int64
#  9   estrato                                       28607 non-null  float64
#  10  residentes_hogar                              28691 non-null  int64
#  11  d_01_aporta_dinero_hogar                      28691 non-null  int64
#  12  d_03_actividad_economica_empresa_negocio      28691 non-null  int64
#  13  d_04_cargo                                    28691 non-null  int64
#  14  d_08_estado_salud                             28691 non-null  int64
#  15  d_09_deprimido                                28691 non-null  int64
#  16  d_10_poco_interes                             28691 non-null  int64
#  17  d_11_h_riesgo_fumar_marihuana_frecuentemente  28691 non-null  int64
#  18  d_11_k_riesgo_cocaina_frecuentemente          28691 non-null  int64
#  19  d_11_n_riesgo_fumar_basuco_frecuentemente     28691 non-null  int64
#  20  d_12_b_consumo_sp_barrio                      28691 non-null  int64
#  21  d_12_c_expendio_sp_barrio                     28691 non-null  int64
#  22  d2_01_etnia                                   28691 non-null  int64
#  23  d2_03_estado_civil                            28691 non-null  int64
#  24  d2_04_num_hijos                               28691 non-null  int64
#  25  d2_05_nivel_educativo                         28691 non-null  int64
#  26  g_01_familiares_consumen_sp                   28691 non-null  int64
#  27  g_01_a_num_familiares_consumen_sp             5572 non-null   float64
#  28  g_02_amigos_consumen_sp                       28691 non-null  int64
#  29  g_02_a_num_amigos_consumen_sp                 8152 non-null   float64
#  30  g_03_curiosidad_probar_sp                     28691 non-null  int64
#  31  g_05_posibilidad_probar_sp                    28691 non-null  int64
#  32  g_06_a_posibilidad_conseguir_marihuana        28691 non-null  int64
#  33  g_06_b_posibilidad_conseguir_cocaina          28691 non-null  int64
#  34  g_06_c_posibilidad_conseguir_basuco           28691 non-null  int64
#  35  g_06_j_posibilidad_conseguir_heroina          28691 non-null  int64
#  36  g_07_alguien_ofrecio_comprar_probar_sp        28691 non-null  int64
#  37  g_08_a_ofrecieron_marihuana                   8966 non-null   float64
#  38  g_08_b_ofrecieron_cocaina                     8966 non-null   float64
#  39  g_08_c_ofrecieron_basuco                      8966 non-null   float64
#  40  g_08_e_ofrecieron_heroina                     8966 non-null   float64
#  41  g_11_f_consumio_alguna_vez_marihuana          28691 non-null  int64
#  42  g_11_f_anios_consumio_marihuana               2638 non-null   float64
#  43  g_11_g_consumio_alguna_vez_cocaina            28691 non-null  int64
#  44  g_11_g_anios_consumio_cocaina                 672 non-null    float64
#  45  g_11_h_consumio_alguna_vez_basuco             28691 non-null  int64
#  46  g_11_h_anios_consumio_basuco                  2638 non-null   float64
#  47  g_11_j_consumio_alguna_vez_heroina            28691 non-null  int64
#  48  g_11_j_anios_consumio_heroina                 36 non-null     float64
#  49  r_01_accidente_laboral                        28691 non-null  int64
#  50  r_02_consumio_sp_en_accidente_laboral         1030 non-null   float64
#  51  r_03_estuvo_enfermo_accidentado_ult_30d       28691 non-null  int64
#  52  r_04_consecuencia_sp                          2654 non-null   float64
#  53  r_05_existe_reglamento_sp_trabajo             28691 non-null  int64
#  54  r_06_prevencion_sp_trabajo                    28691 non-null  int64
#  55  r_07_programa_ayuda_sp                        28691 non-null  int64
#  56  r_08_c_consumo_marihuana_trabajo              28691 non-null  int64
#  57  r_08_d_consumo_cocaina_trabajo                28691 non-null  int64
#  58  r_09_rendimiento_disminuido_trabajo           28691 non-null  int64
# dtypes: float64(13), int64(44), object(2)
# memory usage: 12.9+ MB
